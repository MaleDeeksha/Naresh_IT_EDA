# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %% [markdown]
# **read the data**

# %%
file_location="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **head**

# %%
#your name of the dataframe:visa_df
#<package_name>.<method name>
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# **tail**

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **shape**

# %%
visa_df.shape
#number of rows-25480
#number of column -12
# Out:
# (25480, 12)

# %%
type(visa_df.shape)
# Out:
# tuple

# %%
visa_df.shape[0],visa_df.shape[1]
print("numbers of rows are:",visa_df.shape[0])
print("numbers of columns are:",visa_df.shape[1])
# Out:
# numbers of rows are: 25480
# numbers of columns are: 12

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# $size$

# %%
visa_df.size
#visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %% [markdown]
# $len$

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# $columns$

# %%
cols=visa_df.columns
cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols_list=cols.to_list()
type(cols_list)
# Out:
# list

# %% [markdown]
# **dtypes**

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $info$

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $isnull$

# %%
##visa_df.isnull()   or
visa_df.isna().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
**not collable**
  - it is a function but you provided brackets
  - remove those brackets
**bound method or built in fuction**
  - plese provide brackets
**attribute error**
  - you rovided a method which does not have
  - please chech the spelling
  - or use to check the method existed or not

# %%
visa_df.dtypes
dtype=dict(visa_df.dtypes)
for i in dtype:
    if dtype[i]=='object':
        print(i,dtype[i])
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# region_of_employment object
# unit_of_wage object
# full_time_position object
# case_status object

# %%
#same code with comprehension
visa_df.dtypes
dtype=dict(visa_df.dtypes)
cat_cols=[i for i in dtype if dtype[i]=='object']
num_cols=[i for i in dtype if dtype[i]!='object']
print("categorical columns are:",cat_cols)
print("numerical columns are:",num_cols )
# Out:
# categorical columns are: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# numerical columns are: ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **same above code with include and exclude**

# %%
print('categorical:',visa_df.select_dtypes(include=object).columns)
print('numerical:',visa_df.select_dtypes(exclude=object).columns)
# Out:
# categorical: Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')
# numerical: Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#with comprehension
visa_df.dtypes
dtype=dict(visa_df.dtypes)
cat_cols=[i for i in dtype if dtype[i]=='object']
num_cols=[i for i in dtype if dtype[i]!='object']
print("categorical columns are:",cat_cols)
print("numerical columns are:",num_cols )
#using include and exclude
print('categorical:',visa_df.select_dtypes(include=object).columns)
print('numerical:',visa_df.select_dtypes(exclude=object).columns)

# %% [markdown]
# $take-loc-iloc$

# %%
visa_df.take([1,2,3])
#by default axis=0
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 1         83425.65         Year                  Y   Certified
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied

# %%
visa_df.take([1,2,3],axis=1)
# Out:
#       continent education_of_employee has_job_experience
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300]).take([2,3],axis=1)
# Out:
#     education_of_employee has_job_experience
# 100              Master's                  Y
# 200             Doctorate                  Y
# 300              Master's                  Y

# %%
visa_df.take([1,2,3])#rowa and all the columns
visa_df.take([1,2,3],axis=1)
visa_df.take([100,200,300]).take([2,3],axis=1)
# Out:
#     education_of_employee has_job_experience
# 100              Master's                  Y
# 200             Doctorate                  Y
# 300              Master's                  Y

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
file_location="C:\\Users\\hp\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_location)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[<rows>,<columns>]
visa_df.iloc[<start:end>,<start:end>]
visa_df.iloc[[rows index],[columns index]]

# %%
visa_df.iloc[5:10,2:6]
# Out:
#   education_of_employee has_job_experience requires_job_training  \
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N
# 7            Bachelor's                  Y                     N
# 8            Bachelor's                  N                     N
# 9             Doctorate                  Y                     N
#
#    no_of_employees
# 5             2339
# 6             4985
# 7             3035
# 8             4810
# 9             2251

# %%
visa_df.iloc[[100,12]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 12    EZYV13      Asia            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 12                      N           123876         1963            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 12          28663.05         Year                  Y   Certified

# %%
visa_df.iloc[:,:2]
# Out:
#          case_id continent
# 0         EZYV01      Asia
# 1         EZYV02      Asia
# 2         EZYV03      Asia
# 3         EZYV04      Asia
# 4         EZYV05    Africa
# ...          ...       ...
# 25475  EZYV25476      Asia
# 25476  EZYV25477      Asia
# 25477  EZYV25478      Asia
# 25478  EZYV25479      Asia
# 25479  EZYV25480      Asia
#
# [25480 rows x 2 columns]

# %%
visa_df.iloc[4:11,:]
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 4   EZYV05         Africa              Master's                  Y
# 5   EZYV06           Asia              Master's                  Y
# 6   EZYV07           Asia            Bachelor's                  N
# 7   EZYV08  North America            Bachelor's                  Y
# 8   EZYV09           Asia            Bachelor's                  N
# 9   EZYV10         Europe             Doctorate                  Y
# 10  EZYV11           Asia              Master's                  N
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 4                      N             1082         2005                South
# 5                      N             2339         2012                South
# 6                      N             4985         1994                South
# 7                      N             3035         1924                 West
# ...

# %%
rows=[100,200,300]
cols=['education_of_employee','has_job_experience']
visa_df.loc[rows,cols]
# Out:
#     education_of_employee has_job_experience
# 100              Master's                  Y
# 200             Doctorate                  Y
# 300              Master's                  Y

# %%
**note**
-  iloc takes only numerical entry
-  loc
