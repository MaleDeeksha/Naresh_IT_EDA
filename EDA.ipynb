# %% [markdown]
# ######  Eploratory data analysis  ############
# - pandas (data frame analysis)
# - numpy(number python math package)
# - matplotlib(plotting)
# - seaborn(plotting)
# - ploty(plotting)
# - bokhe(plotting)#plotting is nothing but visualization/graph
# ######  machine learning  #########
# - scikit (ml model will available)
# - stats (statistics models)
# ######  deep learning  ######
# - tensorflow  (developed by google)
# - keras
# - torch
# - opencv (computer vision)
# #######  NLP  ##########
# - NLTK  (Natural laguage toll kit)
# - scipy
# ########generative AI#############
# - chatgpt is developed by open AI+Azure
# - Makersuite is deeveloped by google
# - gemini is developed by google
# ###### company based packages  ##########
# - hugggingface
# - transformers BERT Model
# - AllenNLP
# #######  SPL  ############
# - Random
# - math
# - api      :flask
# - ui apps    :streamlit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
file_location="Visadataset - Visadataset.csv"

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
pd.read_csv(file_location)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_location="Visadataset - Visadataset.csv"
file=open(file_location)
file.read()
pd.read_csv(file_location)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_location="C:\\Users\\hp\Downloads\\bank - bank.csv"
file=open(file_location)
file.read()
pd.read_csv(file_location)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# $method-1$
# **creating dataframe using list**

# %%
Names=['ramesh','suresh','sathish']
Age=[20,25,30]
df2=pd.DataFrame(zip(Names,Age))

# %%
df2
# Out:
#          0   1
# 0   ramesh  20
# 1   suresh  25
# 2  sathish  30

# %% [markdown]
# $method-2$
# **update  column names**

# %%
Names=['ramesh','suresh','sathish']
Age=[20,25,30]
df2=pd.DataFrame(zip(Names,Age),columns=['Names','Age'])

# %%
df2
# Out:
#      Names  Age
# 0   ramesh   20
# 1   suresh   25
# 2  sathish   30

# %% [markdown]
# $method-3$
# **update index**

# %%
Names=['ramesh','suresh','sathish']
Age=[20,25,30]
df2=pd.DataFrame(zip(Names,Age),
                columns=['Names','Age'],
              index=['i','ii','iii'])
df2
# Out:
#        Names  Age
# i     ramesh   20
# ii    suresh   25
# iii  sathish   30

# %%
#$method-4$
#**change entire column data**

# %% [markdown]
# $method-5$
# **create a new column**

# %%
df2['city']=['hyd','mumbai','banguluru']
df2
# Out:
#        Names  Age       city
# i     ramesh   20        hyd
# ii    suresh   25     mumbai
# iii  sathish   30  banguluru

# %% [markdown]
# **add new rows**

# %%
df2=pd.DataFrame(zip(Names,Age),
             columns=['Names','Age'],
            index=[0,1,2])
df2
# Out:
#      Names  Age
# 0   ramesh   20
# 1   suresh   25
# 2  sathish   30

# %%
len(df2.index)
# Out:
# 3

# %%
df2.loc[3]=['deeksha',23]

# %%
df2.loc['a']=['honey',25]
df2
# Out:
#      Names  Age
# 0   ramesh   20
# 1   suresh   25
# 2  sathish   30
# 3  deeksha   23
# a    honey   25

# %% [markdown]
# **drop column**

# %%
Names=['ramesh','suresh','sathish']
Age=[20,25,30]
df2=pd.DataFrame(zip(Names,Age),
                columns=['Names','Age'],
              index=[0,1,2])
df2['city']=['hyd','mumbai','banguluru']
df2
# Out:
#      Names  Age       city
# 0   ramesh   20        hyd
# 1   suresh   25     mumbai
# 2  sathish   30  banguluru

# %%
df2.drop('city',axis=1,inplace=True)

# %%
df2
# Out:
#      Names  Age
# 0   ramesh   20
# 1   suresh   25
# 2  sathish   30

# %% [markdown]
# **drop row**

# %%
df2.drop(2,inplace=True)

# %%
df2
# Out:
#     Names  Age
# 0  ramesh   20
# 1  suresh   25

# %% [markdown]
# $method-6$
# **chandex index values**

# %%
df1.drop(1,inplace=True)

# %%
df1
# Out:
#          0   1
# 0   ramesh  20
# 2  sathish  30

# %%
df2.to_csv("C:\\Users\\hp\Downloads\\output.csv",index=False)

# %%
pd.read_csv("C:\\Users\\hp\Downloads\\output.csv")
# Out:
#     Names  Age
# 0  ramesh   20
# 1  suresh   25

# %% [markdown]
# $step-9$
# **save the df1 in local**

# %% [markdown]
# **create a Dataframe using dictionary**

# %%
d1={'Names':['ramesh','suresh','sathish'],
   'Age':[20,25,30]}
d1
# Out:
# {'Names': ['ramesh', 'suresh', 'sathish'], 'Age': [20, 25, 30]}

# %%
pd.DataFrame(d1)
# Out:
#      Names  Age
# 0   ramesh   20
# 1   suresh   25
# 2  sathish   30

# %%
$method-3$
**

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import random
even_list=[]
for i in range(5):
    num=random.randint(20,50)
    if num%2==0:
        even_list.append(num)
even_list
# Out:
# [40, 46, 28, 48, 26]

# %%
df1['Even']=even_list

# %%
df1['Odd']=[1,3,5,7]

# %%
df1
# Out:
# {'Fruites': ['banana', 'apple', 'mango'],
#  'Prices': [60, 100, 50],
#  'Even': [40, 46, 28, 48, 26],
#  'Odd': [1, 3, 5, 7]}

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import random
even_list=[]
odd_list=[]
for i in range(0,10):
    num=random.randint(20,50)
    if num%2==0:
        even_list.append(num)
    else:
        odd_list.append(num)
print(even_list)
print(odd_list)
# Out:
# [28, 40, 40, 50]
# [33, 21, 25, 49, 35, 23]

# %%
df1=pd.DataFrame(zip(even_list,odd_list),columns=['Even','Odd'])
df1
# Out:
#    Even  Odd
# 0    28   33
# 1    40   21
# 2    40   25
# 3    50   49
